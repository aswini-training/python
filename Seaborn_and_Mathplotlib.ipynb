# %% [markdown]
# <a href="https://colab.research.google.com/github/aswini-training/python/blob/main/Seaborn_and_Mathplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pie chart and bar chart for Men Top 20-30 states.

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from warnings import filterwarnings
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/dataset/dataset_csv/dataset-powerlifting-csv/openpowerlifting-2021-12-10-b420db66.csv')
men_df = df[df['Sex'] == 'M']
men_by_state = men_df.groupby('State').size()
sorted_states = men_by_state.sort_values(ascending=False)
top_20_to_30_states = sorted_states.iloc[19:29]
print(top_20_to_30_states)

#creating a bar graph using Seaborn:
sns.barplot(x=top_20_to_30_states.index, y=top_20_to_30_states.values, palette='bright')
plt.xlabel('State')
plt.ylabel('Number of Men')
plt.title('Top 20 to 30 States')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-14-fb24d953fc9c>:9: DtypeWarning: Columns (33,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/dataset/dataset_csv/dataset-powerlifting-csv/openpowerlifting-2021-12-10-b420db66.csv')
# State
# MA    5273
# OK    5075
# BC    4823
# TN    4680
# OR    4632
# NM    4364
# MI    4330
# AB    4184
# AL    4133
# IN    4036
# dtype: int64
# <ipython-input-14-fb24d953fc9c>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_20_to_30_states.index, y=top_20_to_30_states.values, palette='bright')

# %%
#creating pie chart using Matplotlib

import pandas as pd
import matplotlib.pyplot as plt
from warnings import filterwarnings
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/dataset/dataset_csv/dataset-powerlifting-csv/openpowerlifting-2021-12-10-b420db66.csv')
men_df = df[df['Sex'] == 'M']
men_by_state = men_df.groupby('State').size()
sorted_states = men_by_state.sort_values(ascending=False)
top_20_to_30_states = sorted_states.iloc[19:29]
plt.pie(top_20_to_30_states, labels=top_20_to_30_states.index, autopct='%1.0f%%')
plt.title('Top 20 to 30 States')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-19-4da13e7f7846>:8: DtypeWarning: Columns (33,35,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/dataset/dataset_csv/dataset-powerlifting-csv/openpowerlifting-2021-12-10-b420db66.csv')
